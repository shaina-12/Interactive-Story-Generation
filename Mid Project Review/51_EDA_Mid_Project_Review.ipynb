# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Adventure Stories

# %%
a_train = pd.read_csv('adventure_train.csv')
a_val = pd.read_csv('adventure_val.csv')
a_test = pd.read_csv('adventure_test.csv')

# %%
a_train.head()
# Out:
#                                               Prompt  \
# 0                       In the heart of dense jungle
# 1        Captain Morgan and his crew set sail aboard
# 2                n the heart of the rugged mountains
# 3  In a realm shrouded in darkness, a courageous ...
# 4  Beneath the relentless gaze of the scorching s...
#
#                                                Story
# 0  In the heart of dense jungle lay the fabled Te...
# 1  Captain Morgan and his crew set sail aboard th...
# 2  In the heart of the rugged mountains lay a sec...
# 3  In a realm shrouded in darkness, a courageous ...
# 4  Beneath the relentless gaze of the scorching s...

# %%
a_val.head()
# Out:
#                                               Prompt  \
# 0  In the realm beneath the earth's surface, wher...
# 1     In the heart of the Amazon rainforest, a realm
# 2  At the crown of the world, where the heavens s...
#
#                                                Story
# 0  In the realm beneath the earth's surface, wher...
# 1  In the heart of the Amazon rainforest, a realm...
# 2  At the crown of the world, where the heavens s...

# %%
a_test.head()
# Out:
#                                               Prompt  \
# 0  In the heart of the Whispering Woods, where th...
# 1   In a world where the sky was a vast canvas of...
# 2  In the heart of a vast desert, where the sands...
#
#                                                Story
# 0  In the heart of the Whispering Woods, where th...
# 1  In a world where the sky was a vast canvas of ...
# 2  In the heart of a vast desert, where the sands...

# %%
# taken reference from https://github.com/shaina-12/CSE508_Winter2024_A2_MT23139/blob/main/CSE508_Winter2024_A2_MT23139_Code_File.ipynb
# taken reference from https://github.com/shaina-12/CSE508_Winter2024_A1_MT23139/blob/main/CSE508_Winter2024_A1_MT23139_Code_File.py

def tokenize_words(text):
    return nltk.word_tokenize(text, language="english")

# taken reference from https://github.com/shaina-12/CSE508_Winter2024_A1_MT23139/blob/main/CSE508_Winter2024_A1_MT23139_Code_File.py
# taken reference from https://www.geeksforgeeks.org/python-remove-punctuation-from-string/

def remove_punctuation(text):
    p_text = ""
    punc = '''!?@#~-[]{}+=//\$()%;:'"\,<>./^&*_'''
    for i in range(len(text)):
        if text[i] not in punc:
            p_text += text[i]
    return p_text

def processing(text):
    #print(text)
    text = remove_punctuation(text).lower()
    text = tokenize_words(text)
    return text

# %%
a_train_story = list(a_train['Story'])
a_val_story = list(a_val['Story'])
a_test_story = list(a_test['Story'])

# %%
a_train_tokens_length = []
a_val_tokens_length = []
a_test_tokens_length = []

for i in range(len(a_train_story)):
  a_train_tokens_length.append(len(processing(a_train_story[i])))

for i in range(len(a_val_story)):
  a_val_tokens_length.append(len(processing(a_val_story[i])))

for i in range(len(a_test_story)):
  a_test_tokens_length.append(len(processing(a_test_story[i])))

# %%
tok_length = np.array([max(a_train_tokens_length), max(a_val_tokens_length), max(a_test_tokens_length)])
x = np.arange(3)
plt.bar(x,tok_length)
labels = ['train set', 'validation set', 'test set']
plt.xticks(x, labels)
plt.xlabel('Data Spit')
plt.ylabel('Max. No. of Tokens in Story')
plt.title('Max. No. of Tokens in Adventure Stories of Each Split')
plt.show()

# %% [markdown]
# # Horror Stories

# %%
a_train = pd.read_csv('horror_train.csv')
a_val = pd.read_csv('horror_val.csv')
a_test = pd.read_csv('horror_test.csv')

# %%
a_train.head()
# Out:
#                                               Prompt  \
# 0  Pioneers used to entertain themselves by telli...
# 1        A boy was digging at the edge of the garden
# 2  My uncle was walking down a lonely dirt road o...
# 3  There was an old woman who lived all by hersel...
# 4  There was a haunted house where every night a ...
#
#                                                Story
# 0  Pioneers used to entertain themselves by telli...
# 1  A boy was digging at the edge of the garden wh...
# 2  My uncle was walking down a lonely dirt road o...
# 3  There was an old woman who lived all by hersel...
# 4  There was a haunted house where every night a ...

# %%
a_val.head()
# Out:
#                                               Prompt  \
# 0  One time a preacher went to see if he could pu...
# 1  A young man and his wife were on a trip to vis...
# 2  Some boys and girls were at a party one night....
#
#                                                Story
# 0  One time a preacher went to see if he could pu...
# 1  A young man and his wife were on a trip to vis...
# 2  Some boys and girls were at a party one night....

# %%
a_test.head()
# Out:
#                                               Prompt  \
# 0  Two farmhands shared a room. One slept at the ...
# 1  A young woman in town married a man from anoth...
# 2  A man named Joseph Blackwell came to Philadelp...
#
#                                                Story
# 0  Two farmhands shared a room. One slept at the ...
# 1  A young woman in town married a man from anoth...
# 2  A man named Joseph Blackwell came to Philadelp...

# %%
a_train_story = list(a_train['Story'])
a_val_story = list(a_val['Story'])
a_test_story = list(a_test['Story'])

# %%
a_train_tokens_length = []
a_val_tokens_length = []
a_test_tokens_length = []

for i in range(len(a_train_story)):
  a_train_tokens_length.append(len(processing(a_train_story[i])))

for i in range(len(a_val_story)):
  a_val_tokens_length.append(len(processing(a_val_story[i])))

for i in range(len(a_test_story)):
  a_test_tokens_length.append(len(processing(a_test_story[i])))

# %%
tok_length = np.array([max(a_train_tokens_length), max(a_val_tokens_length), max(a_test_tokens_length)])
x = np.arange(3)
plt.bar(x,tok_length)
labels = ['train set', 'validation set', 'test set']
plt.xticks(x, labels)
plt.xlabel('Data Spit')
plt.ylabel('Max. No. of Tokens in Story')
plt.title('Max. No. of Tokens in Horror Stories of Each Split')
plt.show()

# %% [markdown]
# # Scifi Stories

# %%
a_train = pd.read_csv('scifi_train.csv')
a_val = pd.read_csv('scifi_val.csv')
a_test = pd.read_csv('scifi_test.csv')

# %%
a_train.head()
# Out:
#                                               Prompt  \
# 0  In the desolate wasteland of a post-apocalypti...
# 1  In the labyrinth of time, a group of intrepid ...
# 2  Dr. Evelyn Clarke, a brilliant physicist, find...
# 3   In the sprawling expanse of the cosmos, tensions
# 4  In the not-so-distant future, humanity stands ...
#
#                                                Story
# 0  In the desolate wasteland of a post-apocalypti...
# 1  In the labyrinth of time, a group of intrepid ...
# 2  Dr. Evelyn Clarke, a brilliant physicist, find...
# 3  In the sprawling expanse of the cosmos, tensio...
# 4  In the not-so-distant future, humanity stands ...

# %%
a_val.head()
# Out:
#                                               Prompt  \
# 0  In the twilight of humanity, a courageous crew...
# 1  In the city where minds intertwine like thread...
# 2  In a landmark breakthrough, scientists cracked...
#
#                                                Story
# 0  In the twilight of humanity, a courageous crew...
# 1  In the city where minds intertwine like thread...
# 2  In a landmark breakthrough, scientists cracked...

# %%
a_test.head()
# Out:
#                                               Prompt  \
# 0  In the immersive landscape of virtual reality,...
# 1  Dr. Elena Reyes, a brilliant linguist, was thr...
# 2  Solaris tells the story of a space station orb...
#
#                                                Story
# 0  In the immersive landscape of virtual reality,...
# 1  Dr. Elena Reyes, a brilliant linguist, was thr...
# 2  Solaris tells the story of a space station orb...

# %%
a_train_story = list(a_train['Story'])
a_val_story = list(a_val['Story'])
a_test_story = list(a_test['Story'])

# %%
a_train_tokens_length = []
a_val_tokens_length = []
a_test_tokens_length = []

for i in range(len(a_train_story)):
  a_train_tokens_length.append(len(processing(a_train_story[i])))

for i in range(len(a_val_story)):
  a_val_tokens_length.append(len(processing(a_val_story[i])))

for i in range(len(a_test_story)):
  a_test_tokens_length.append(len(processing(a_test_story[i])))

# %%
tok_length = np.array([max(a_train_tokens_length), max(a_val_tokens_length), max(a_test_tokens_length)])
x = np.arange(3)
plt.bar(x,tok_length)
labels = ['train set', 'validation set', 'test set']
plt.xticks(x, labels)
plt.xlabel('Data Spit')
plt.ylabel('Max. No. of Tokens in Story')
plt.title('Max. No. of Tokens in Scifi Stories of Each Split')
plt.show()

# %% [markdown]
# # General

# %%
a_df = pd.concat([pd.read_csv('adventure_train.csv'), pd.read_csv('adventure_val.csv'), pd.read_csv('adventure_test.csv')], ignore_index=True, axis=0)
h_df = pd.concat([pd.read_csv('horror_train.csv'), pd.read_csv('horror_val.csv'), pd.read_csv('horror_test.csv')], ignore_index=True, axis=0)
s_df = pd.concat([pd.read_csv('scifi_train.csv'), pd.read_csv('scifi_val.csv'), pd.read_csv('scifi_test.csv')], ignore_index=True, axis=0)

# %%
x = np.arange(3)
y = np.array([len(a_df), len(h_df), len(s_df)])
plt.bar(x,y)
labels = ['Adventure', 'Horror', 'Scifi']
plt.xticks(x, labels)
plt.xlabel('Themes')
plt.ylabel('No. of Stories')
plt.title('No. of Stories per Theme')
plt.show()
